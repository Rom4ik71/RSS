# %%
import feedparser
import unidecode
import urllib.request
from urllib.request import urlopen
import sqlite3
from __future__ import unicode_literals, print_function
from PyQt5 import QtCore, QtGui, QtWidgets


def parser(rssline):
    data=[]
    rss = rssline
    feed = feedparser.parse(rss)
    website = feed["feed"]["title"]
    for key in feed["entries"]:
        title = key["title"]
        link = unidecode.unidecode(key["link"])
        summary = key["summary"]
        data.append((title, link, website, summary))
    return data

def ins(site,zagolovok,text,isochnik,kategory):
    con=sqlite3.connect('RSS.db')
    kyrsor=con.cursor()
    kyrsor.execute("insert into Общая values (?,?,?,?)",[(site),(zagolovok),(text),(isochnik)])
    con.commit()
    con.close()
    if kategory=="Автомобили":
        con=sqlite3.connect('RSS.db')
        kyrsor=con.cursor()
        kyrsor.execute("insert into Автомобили values (?,?,?,?)",[(site),(zagolovok),(text),(isochnik)])
        con.commit()
        con.close()
    if kategory=="Игры":
        con=sqlite3.connect('RSS.db')
        kyrsor=con.cursor()
        kyrsor.execute("insert into Игры values (?,?,?,?)",[(site),(zagolovok),(text),(isochnik)])
        con.commit()
        con.close()
    if kategory=="Медецина":
        con=sqlite3.connect('RSS.db')
        kyrsor=con.cursor()
        kyrsor.execute("insert into Медецина values (?,?,?,?)",[(site),(zagolovok),(text),(isochnik)])
        con.commit()
        con.close()
    if kategory=="Новости":
        con=sqlite3.connect('RSS.db')
        kyrsor=con.cursor()
        kyrsor.execute("insert into Новости values (?,?,?,?)",[(site),(zagolovok),(text),(isochnik)])
        con.commit()
        con.close()
    if kategory=="Обучение":
        con=sqlite3.connect('RSS.db')
        kyrsor=con.cursor()
        kyrsor.execute("insert into Обучение values (?,?,?,?)",[(site),(zagolovok),(text),(isochnik)])
        con.commit()
        con.close()
    if kategory=="Ремонт":
        con=sqlite3.connect('RSS.db')
        kyrsor=con.cursor()
        kyrsor.execute("insert into Ремонт values (?,?,?,?)",[(site),(zagolovok),(text),(isochnik)])
        con.commit()
        con.close()
    if kategory=="Спорт":
        con=sqlite3.connect('RSS.db')
        kyrsor=con.cursor()
        kyrsor.execute("insert into Спорт values (?,?,?,?)",[(site),(zagolovok),(text),(isochnik)])
        con.commit()
        con.close()

def delit(a,kategory):
    conn = sqlite3.connect("RSS.db")
    cursor = conn.cursor()
    cursor.execute("DELETE FROM Общая WHERE Источники = ?",[a])
    conn.commit()
    conn.close()
    if kategory=="Автомобили":
        conn = sqlite3.connect("RSS.db")
        cursor = conn.cursor()
        cursor.execute("DELETE FROM Автомобили WHERE Источники = ?",[a])
        conn.commit()
        conn.close()
    if kategory=="Игры":
        conn = sqlite3.connect("RSS.db")
        cursor = conn.cursor()
        cursor.execute("DELETE FROM Игры WHERE Источники = ?",[a])
        conn.commit()
        conn.close()
    if kategory=="Медецина":
        conn = sqlite3.connect("RSS.db")
        cursor = conn.cursor()
        cursor.execute("DELETE FROM Медецина WHERE Источники = ?",[a])
        conn.commit()
        conn.close()
    if kategory=="Новости":
        conn = sqlite3.connect("RSS.db")
        cursor = conn.cursor()
        cursor.execute("DELETE FROM Новости WHERE Источники = ?",[a])
        conn.commit()
        conn.close()
    if kategory=="Обучение":
        conn = sqlite3.connect("RSS.db")
        cursor = conn.cursor()
        cursor.execute("DELETE FROM Обучение WHERE Источники = ?",[a])
        conn.commit()
        conn.close()
    if kategory=="Ремонт":
        conn = sqlite3.connect("RSS.db")
        cursor = conn.cursor()
        cursor.execute("DELETE FROM Ремонт WHERE Источники = ?",[a])
        conn.commit()
        conn.close()
    if kategory=="Спорт":
        conn = sqlite3.connect("RSS.db")
        cursor = conn.cursor()
        cursor.execute("DELETE FROM Спорт WHERE Источники = ?",[a])
        conn.commit()
        conn.close()

def read(kategory):
    A=[]
    B=[]
    C=[]
    D=[]
    baze=[]
    if kategory=="Общая":
        con=sqlite3.connect('RSS.db')
        with con:
            cur = con.cursor()    
            cur.execute("SELECT * FROM Общая")
            while True:
                row = cur.fetchone()
                if row == None:
                    break
                A.append(row[0])
                B.append(row[1])
                C.append(row[2])
                D.append(row[3])
        con.commit()
        con.close()
    if kategory=="Автомобили":
        con=sqlite3.connect('RSS.db')
        with con:
            cur = con.cursor()    
            cur.execute("SELECT * FROM Автомобили")
            while True:
                row = cur.fetchone()
                if row == None:
                    break
                A.append(row[0])
                B.append(row[1])
                C.append(row[2])
                D.append(row[3])
        con.commit()
        con.close()
    if kategory=="Игры":
        con=sqlite3.connect('RSS.db')
        with con:
            cur = con.cursor()    
            cur.execute("SELECT * FROM Игры ")
            while True:
                row = cur.fetchone()
                if row == None:
                    break
                A.append(row[0])
                B.append(row[1])
                C.append(row[2])
                D.append(row[3])
        con.commit()
        con.close()
    if kategory=="Медецина":
        con=sqlite3.connect('RSS.db')
        with con:
            cur = con.cursor()    
            cur.execute("SELECT * FROM Медецина ")
            while True:
                row = cur.fetchone()
                if row == None:
                    break
                A.append(row[0])
                B.append(row[1])
                C.append(row[2])
                D.append(row[3])
        con.commit()
        con.close()
    if kategory=="Новости":
        con=sqlite3.connect('RSS.db')
        with con:
            cur = con.cursor()    
            cur.execute("SELECT * FROM Новости")
            while True:
                row = cur.fetchone()
                if row == None:
                    break
                A.append(row[0])
                B.append(row[1])
                C.append(row[2])
                D.append(row[3])
        con.commit()
        con.close()
    if kategory=="Обучение":
        con=sqlite3.connect('RSS.db')
        with con:
            cur = con.cursor()    
            cur.execute("SELECT * FROM Обучение")
            while True:
                row = cur.fetchone()
                if row == None:
                    break
                A.append(row[0])
                B.append(row[1])
                C.append(row[2])
                D.append(row[3])
        con.commit()
        con.close()
    if kategory=="Ремонт":
        con=sqlite3.connect('RSS.db')
        with con:
            cur = con.cursor()    
            cur.execute("SELECT * FROM Ремонт")
            while True:
                row = cur.fetchone()
                if row == None:
                    break
                A.append(row[0])
                B.append(row[1])
                C.append(row[2])
                D.append(row[3])
        con.commit()
        con.close()
    if kategory=="Спорт":
        con=sqlite3.connect('RSS.db')
        with con:
            cur = con.cursor()    
            cur.execute("SELECT * FROM Спорт")
            while True:
                row = cur.fetchone()
                if row == None:
                    break
                A.append(row[0])
                B.append(row[1])
                C.append(row[2])
                D.append(row[3])
        con.commit()
        con.close()
    baze=[A,B,C,D]
    return baze

def fulparserdatabaze(site,kategory):
    P=parser(site)
    for i in range (0,len(P)):
        ins(P[i][1],P[i][0],P[i][3],P[i][2],kategory)
        
import tkinter as tk
from tkinter import ttk
from tkinter import messagebox as mb
import sys
try:
    import Tkinter
    import tkFont
except ImportError: 
    import tkinter as Tkinter
    import tkinter.font as tkFont
    
class Main(tk.Frame):#Frame - контейнер\онструктор класса

    def __init__(self, root):
        super().__init__(root)
        self.init_main()

    def init_main(self):
        toolbar=tk.Frame(bg="white",bd=2)
        toolbar.pack(side=tk.TOP,fill=tk.X)

        self.add_png=tk.PhotoImage(file="иконка_добавить_rss.png")
        btn_open_win=tk.Button(toolbar,text="Добавить RSS Ленту",command=self.open1,bd=0,compound=tk.TOP,image=self.add_png)
        btn_open_win.pack(side=tk.LEFT)

        self.add_png2=tk.PhotoImage(file="иконка_списка.png")
        btn_open_win2=tk.Button(toolbar,text="Ваши RSS Ленты",command=self.open2,bd=0,compound=tk.TOP,image=self.add_png2)
        btn_open_win2.pack(side=tk.LEFT)

    def open1(self):
        Child1()
    def open2(self):
        Child2()

class Child1(tk.Toplevel):  
    
    def ins1(self):
        n=self.entry_site.get()
        b=self.combobox_category.get()
        fulparserdatabaze(n,b)
        self.destroy()
        
    
    def __init__(self):
        super().__init__(root)
        self.init_child1()

    def init_child1(self):

        self.title("Добавление RSS Ленты")
        self.geometry("320x150")
        self.resizable(False,False)

        label_site=tk.Label(self,text="Ссылка RSS Ленты:")
        label_site.place(x=10,y=20)

        label_category=tk.Label(self,text="Категория:")
        label_category.place(x=30,y=60)

        self.combobox_category=ttk.Combobox(self,values=["Общая","Автомобили","Игры","Медецина","Новости","Обучение","Ремонт","Спорт"])
        self.combobox_category.current(0)
        self.combobox_category.place(x=140,y=60)
        
        self.entry_site=ttk.Entry(self)
        self.entry_site.place(x=140,y=20)

        btn_save=ttk.Button(self,text="Добавить",command=self.ins1)
        btn_save.place(x=30,y=100)

        btn_out=ttk.Button(self,text="Выход",command=self.destroy)
        btn_out.place(x=230,y=100)
        
        self.grab_set()
        self.focus_set()

class Child2(tk.Toplevel):
    def opencat(self):
        self.tree.delete(*self.tree.get_children())
    def fun(self):
        n=self.combobox_category1.get()
        self.data=read(n)
        self.pref=[]
        
        for i in range(0,len(self.data[0])):
            for n in range(2):
                self.pref.append(self.data[0:2][n][i])
            self.tree.insert('','end',values=self.pref)
            self.pref=[]
        self.tree.pack()
    def delrss(self):
        delit(self.combobox_news1.get(),"")
        self.destroy()
    def opencategory(self):
        self.opencat()
        self.fun()
    def found(self):
        self.opencat()
        n=self.entry_site.get()
        A=[]
        B=[]
        C=[]
        D=[]
        baze=[]
        n='%'+n+'%'
        con=sqlite3.connect('RSS.db')
        with con:
            cur = con.cursor()    
            cur.execute("SELECT * FROM Общая WHERE Заголовок LIKE ?",(n,))
            while True:
                row = cur.fetchone()
                if row == None:
                    break
                A.append(row[0])
                B.append(row[1])
                C.append(row[2])
                D.append(row[3])
        baze=[A,B,C,D]
        con.commit()
        con.close()
        self.data=baze
        self.pref=[]
        if len(baze)>0:
            for i in range(0,len(self.data[0])):
                for n in range(2):
                    self.pref.append(self.data[0:2][n][i])
                self.tree.insert('','end',values=self.pref)
                self.pref=[]
            self.tree.pack()
    
    
    import webbrowser
    def opennews(self):
        n=self.combobox_news.get()
        A=[]
        n='%'+n+'%'
        con=sqlite3.connect('RSS.db')
        with con:
            cur = con.cursor()    
            cur.execute("SELECT * FROM Общая WHERE Заголовок LIKE ?",(n,))
            while True:
                row = cur.fetchone()
                if row == None:
                    break
                A.append(row[0])
        self.webbrowser.open(A[0])
        
    def __init__(self):
        super().__init__(root)
        self.init_child2()

    def init_child2(self):
        self.title("RSS Ленты")
        self.geometry("955x400")
        self.resizable(False,False)
        
        label_len1=tk.Label(self,text='Кол-во новостей:')
        label_len1.place(x=15,y=340)
        
        label_len=tk.Label(self,text=len(read("Общая")[1]))
        label_len.place(x=50,y=360)
    
        self.tree=ttk.Treeview(self, columns=("Сайт", "Заголовок"), height=15, show="headings")

        self.tree.column("Сайт", width=100, anchor=tk.CENTER)
        self.tree.column("Заголовок", width=850, anchor=tk.CENTER)
        
        
        self.tree.heading("Сайт", text="Сайт")
        self.tree.heading("Заголовок", text="Заголовок")
        

        self.data=read("Общая")
        self.pref=[]
        
        for i in range(0,len(self.data[0])):
            for n in range(2):
                self.pref.append(self.data[0:2][n][i])
            self.tree.insert('','end',values=self.pref)
            self.pref=[]
                
        self.tree.pack()

        btn_out=ttk.Button(self,text="Перейти к новости",command=self.opennews)
        btn_out.place(x=165,y=330)
        
        btn_out=ttk.Button(self,text="Просморт по категории",command=self.opencategory)
        btn_out.place(x=520,y=330)

        btn_out=ttk.Button(self,text='Поиск',command=self.found)
        btn_out.place(x=375,y=330)
        
        btn_out=ttk.Button(self,text="Удалить RSS ленту",command=self.delrss)
        btn_out.place(x=715,y=330)

        btn_out=ttk.Button(self,text="Выход",command=self.destroy)
        btn_out.place(x=860,y=350)

        self.combobox_category1=ttk.Combobox(self,values=["Общая","Автомобили","Игры","Медецина","Новости","Обучение","Ремонт","Спорт"])
        self.combobox_category1.current(0)
        self.combobox_category1.place(x=520,y=370)
        
        self.combobox_news=ttk.Combobox(self,values=read('Общая')[1])
        self.combobox_news.current(0)
        self.combobox_news.place(x=150,y=370)
        
        self.combobox_news1=ttk.Combobox(self,values=list(set(read('Общая')[3])))
        self.combobox_news1.current(0)
        self.combobox_news1.place(x=700,y=370)
        
        self.entry_site=ttk.Entry(self)
        self.entry_site.place(x=350,y=370)
        
        
        self.grab_set()
        self.focus_set()        
        
        
if __name__=="__main__":
    root=tk.Tk()
    app=Main(root)
    app.pack
    root.title("RSS Reader")
    root.geometry("255x150")
    root.resizable(False,False)
    frame=Tkinter.Frame(root)
    frame.place(x=10,y=150)
    root.mainloop()
